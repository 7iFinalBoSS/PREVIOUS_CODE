# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv(r"C:\Users\Lenovo\Desktop\House_Rent_Dataset.csv")

# %%
dataset.head(4)
# Out:
#     Posted On  BHK   Rent  Size            Floor   Area Type  \
# 0  2022-05-18    2  10000  1100  Ground out of 2  Super Area
# 1  2022-05-13    2  20000   800       1 out of 3  Super Area
# 2  2022-05-16    2  17000  1000       1 out of 3  Super Area
# 3  2022-07-04    2  10000   800       1 out of 2  Super Area
#
#               Area Locality     City Furnishing Status  Tenant Preferred  \
# 0                    Bandel  Kolkata       Unfurnished  Bachelors/Family
# 1  Phool Bagan, Kankurgachi  Kolkata    Semi-Furnished  Bachelors/Family
# 2   Salt Lake City Sector 2  Kolkata    Semi-Furnished  Bachelors/Family
# 3               Dumdum Park  Kolkata       Unfurnished  Bachelors/Family
#
#    Bathroom Point of Contact
# 0         2    Contact Owner
# 1         1    Contact Owner
# 2         1    Contact Owner
# 3         1    Contact Owner

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4746 entries, 0 to 4745
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Posted On          4746 non-null   object
#  1   BHK                4746 non-null   int64
#  2   Rent               4746 non-null   int64
#  3   Size               4746 non-null   int64
#  4   Floor              4746 non-null   object
#  5   Area Type          4746 non-null   object
#  6   Area Locality      4746 non-null   object
#  7   City               4746 non-null   object
#  8   Furnishing Status  4746 non-null   object
#  9   Tenant Preferred   4746 non-null   object
#  10  Bathroom           4746 non-null   int64
#  11  Point of Contact   4746 non-null   object
# dtypes: int64(4), object(8)
# memory usage: 445.1+ KB

# %%
dataset.isnull().sum()
# Out:
# Posted On            0
# BHK                  0
# Rent                 0
# Size                 0
# Floor                0
# Area Type            0
# Area Locality        0
# City                 0
# Furnishing Status    0
# Tenant Preferred     0
# Bathroom             0
# Point of Contact     0
# dtype: int64

# %%
datamapping ={
    'furnished':3,
    'Semi-Furnished': 2,
    'Unfurnished':1
    
}

# %%
dataset['Furnishing Status'] = dataset['Furnishing Status'].map(datamapping)
dataset
# Out:
#        Posted On  BHK   Rent  Size            Floor    Area Type  \
# 0     2022-05-18    2  10000  1100  Ground out of 2   Super Area
# 1     2022-05-13    2  20000   800       1 out of 3   Super Area
# 2     2022-05-16    2  17000  1000       1 out of 3   Super Area
# 3     2022-07-04    2  10000   800       1 out of 2   Super Area
# 4     2022-05-09    2   7500   850       1 out of 2  Carpet Area
# ...          ...  ...    ...   ...              ...          ...
# 4741  2022-05-18    2  15000  1000       3 out of 5  Carpet Area
# 4742  2022-05-15    3  29000  2000       1 out of 4   Super Area
# 4743  2022-07-10    3  35000  1750       3 out of 5  Carpet Area
# 4744  2022-07-06    3  45000  1500     23 out of 34  Carpet Area
# 4745  2022-05-04    2  15000  1000       4 out of 5  Carpet Area
#
#                  Area Locality       City  Furnishing Status  \
# 0                       Bandel    Kolkata                1.0
# ...

# %%
datamapping = {
    "Super Area":2,
    "Carpet Area" : 1
    
}

# %%
dataset["Area Type"] = dataset["Area Type"].map(datamapping)
dataset
# Out:
#        Posted On  BHK   Rent  Size            Floor  Area Type  \
# 0     2022-05-18    2  10000  1100  Ground out of 2        2.0
# 1     2022-05-13    2  20000   800       1 out of 3        2.0
# 2     2022-05-16    2  17000  1000       1 out of 3        2.0
# 3     2022-07-04    2  10000   800       1 out of 2        2.0
# 4     2022-05-09    2   7500   850       1 out of 2        1.0
# ...          ...  ...    ...   ...              ...        ...
# 4741  2022-05-18    2  15000  1000       3 out of 5        1.0
# 4742  2022-05-15    3  29000  2000       1 out of 4        2.0
# 4743  2022-07-10    3  35000  1750       3 out of 5        1.0
# 4744  2022-07-06    3  45000  1500     23 out of 34        1.0
# 4745  2022-05-04    2  15000  1000       4 out of 5        1.0
#
#                  Area Locality       City  Furnishing Status  \
# 0                       Bandel    Kolkata                1.0
# 1     Phool Bagan, Kankurgachi    Kolkata                2.0
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4746 entries, 0 to 4745
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Posted On          4746 non-null   object
#  1   BHK                4746 non-null   int64
#  2   Rent               4746 non-null   int64
#  3   Size               4746 non-null   int64
#  4   Floor              4746 non-null   object
#  5   Area Type          4744 non-null   float64
#  6   Area Locality      4746 non-null   object
#  7   City               4746 non-null   object
#  8   Furnishing Status  4066 non-null   float64
#  9   Tenant Preferred   4746 non-null   object
#  10  Bathroom           4746 non-null   int64
#  11  Point of Contact   4746 non-null   object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 445.1+ KB

# %%
datamapping ={
    "Bachelors/Family" : 3,
    "Bachelors" : 2,
    "Family" : 1
}
dataset["Tenant Preferred"] =dataset["Tenant Preferred"].map(datamapping)

# %%
dataset = dataset.drop("Floor",axis= 1)

# %%
dataset
# Out:
#        Posted On  BHK   Rent  Size  Area Type             Area Locality  \
# 0     2022-05-18    2  10000  1100        2.0                    Bandel
# 1     2022-05-13    2  20000   800        2.0  Phool Bagan, Kankurgachi
# 2     2022-05-16    2  17000  1000        2.0   Salt Lake City Sector 2
# 3     2022-07-04    2  10000   800        2.0               Dumdum Park
# 4     2022-05-09    2   7500   850        1.0             South Dum Dum
# ...          ...  ...    ...   ...        ...                       ...
# 4741  2022-05-18    2  15000  1000        1.0              Bandam Kommu
# 4742  2022-05-15    3  29000  2000        2.0      Manikonda, Hyderabad
# 4743  2022-07-10    3  35000  1750        1.0      Himayath Nagar, NH 7
# 4744  2022-07-06    3  45000  1500        1.0                Gachibowli
# 4745  2022-05-04    2  15000  1000        1.0           Suchitra Circle
#
#            City  Furnishing Status  Tenant Preferred  Bathroom  \
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4746 entries, 0 to 4745
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Posted On          4746 non-null   object
#  1   BHK                4746 non-null   int64
#  2   Rent               4746 non-null   int64
#  3   Size               4746 non-null   int64
#  4   Area Type          4744 non-null   float64
#  5   Area Locality      4746 non-null   object
#  6   City               4746 non-null   object
#  7   Furnishing Status  4066 non-null   float64
#  8   Tenant Preferred   4746 non-null   int64
#  9   Bathroom           4746 non-null   int64
#  10  Point of Contact   4746 non-null   object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 408.0+ KB

# %%
dataset = dataset.drop('Posted On',axis = 1)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4746 entries, 0 to 4745
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   BHK                4746 non-null   int64
#  1   Rent               4746 non-null   int64
#  2   Size               4746 non-null   int64
#  3   Area Type          4744 non-null   float64
#  4   Area Locality      4746 non-null   object
#  5   City               4746 non-null   object
#  6   Furnishing Status  4066 non-null   float64
#  7   Tenant Preferred   4746 non-null   int64
#  8   Bathroom           4746 non-null   int64
# dtypes: float64(2), int64(5), object(2)
# memory usage: 333.8+ KB

# %%
dataset = dataset.drop('Area Locality',axis =1)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4746 entries, 0 to 4745
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   BHK                4746 non-null   int64
#  1   Rent               4746 non-null   int64
#  2   Size               4746 non-null   int64
#  3   Area Type          4744 non-null   float64
#  4   City               4746 non-null   object
#  5   Furnishing Status  4066 non-null   float64
#  6   Tenant Preferred   4746 non-null   int64
#  7   Bathroom           4746 non-null   int64
# dtypes: float64(2), int64(5), object(1)
# memory usage: 296.8+ KB

# %%
dataset
# Out:
#       BHK   Rent  Size  Area Type       City  Furnishing Status  \
# 0       2  10000  1100        2.0    Kolkata                1.0
# 1       2  20000   800        2.0    Kolkata                2.0
# 2       2  17000  1000        2.0    Kolkata                2.0
# 3       2  10000   800        2.0    Kolkata                1.0
# 4       2   7500   850        1.0    Kolkata                1.0
# ...   ...    ...   ...        ...        ...                ...
# 4741    2  15000  1000        1.0  Hyderabad                2.0
# 4742    3  29000  2000        2.0  Hyderabad                2.0
# 4743    3  35000  1750        1.0  Hyderabad                2.0
# 4744    3  45000  1500        1.0  Hyderabad                2.0
# 4745    2  15000  1000        1.0  Hyderabad                1.0
#
#       Tenant Preferred  Bathroom
# 0                    3         2
# 1                    3         1
# 2                    3         1
# 3                    3         1
# ...

# %%
x = dataset.iloc[:,0:8]
x =x.drop('Rent',axis = 1)
x.values
# Out:
# array([[2, 1100, 2.0, ..., 1.0, 3, 2],
#        [2, 800, 2.0, ..., 2.0, 3, 1],
#        [2, 1000, 2.0, ..., 2.0, 3, 1],
#        ...,
#        [3, 1750, 1.0, ..., 2.0, 3, 3],
#        [3, 1500, 1.0, ..., 2.0, 1, 2],
#        [2, 1000, 1.0, ..., 1.0, 2, 2]], dtype=object)

# %%
y = dataset.iloc[:,1].values

# %%
y
# Out:
# array([10000, 20000, 17000, ..., 35000, 45000, 15000], dtype=int64)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
ct =ColumnTransformer(transformers =[('encoder', OneHotEncoder(),[0])] ,remainder='passthrough')
x = np.array(ct.fit_transform(x))

# %%
x
# Out:
# array([[0.0, 1.0, 0.0, ..., 1.0, 3, 2],
#        [0.0, 1.0, 0.0, ..., 2.0, 3, 1],
#        [0.0, 1.0, 0.0, ..., 2.0, 3, 1],
#        ...,
#        [0.0, 0.0, 1.0, ..., 2.0, 3, 3],
#        [0.0, 0.0, 1.0, ..., 2.0, 1, 2],
#        [0.0, 1.0, 0.0, ..., 1.0, 2, 2]], dtype=object)

# %%
from sklearn.model_selection import train_test_split 
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state = 0)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4692/3720071279.py in <module>
#       1 from sklearn.linear_model import LinearRegression
#       2 regressor = LinearRegression()
# ----> 3 regressor.fit(x_train,y_train)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in fit(self, X, y, sample_weight)
#     516         accept_sparse = False if self.positive else ['csr', 'csc', 'coo']
#     517
# --> 518         X, y = self._validate_data(X, y, accept_sparse=accept_sparse,
#     519                                    y_numeric=True, multi_output=True)
#     520
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     431                 y = check_array(y, **check_y_params)
#     432             else:
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4692/1051682391.py in <module>
# ----> 1 x_train.info()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'info'
